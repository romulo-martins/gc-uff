# %% [markdown]
# Configurando o PyGithub

# %%
from github import Github

g = Github("token")

# %%
lang = 'javascript'

# %% [markdown]
# Buscando repositórios com mais de 5 mil estrelas de uma determinada linguagem

# %%
result = g.search_repositories(query="language:{0} stars:>5000 is:public".format(lang))

# %% [markdown]
# Métodos para acessar a API do coveralls

# %%
import requests

def get_test_coverage(full_name):
    try:
        resp = requests.get('https://coveralls.io/github/{0}.json'.format(full_name))
        return resp.json()['covered_percent']
    except:
        return None

# get_test_coverage('cucumber/cucumber-ruby')

# %% [markdown]
# Itera sobre os repositórios e busca a cobertura de código

# %%
repos = []
for r in result:
    repo = {
        'id': r.id,
        'name': r.name,
        'full_name': r.full_name,
        'description': r.description,
        'stargazers_count': r.stargazers_count,
        'open_issues_count': r.open_issues_count,
        'language': r.language,
        'test_coverage': get_test_coverage(r.full_name)
    }
    repos.append(repo)

# %%
import pandas as pd

df = pd.DataFrame(repos)
df
# Out:
#                                            description  \
# 0    The https://www.freeCodeCamp.org open source c...
# 1    🖖 Vue.js is a progressive, incrementally-adopt...
# 2    The most popular HTML, CSS, and JavaScript fra...
# 3    A declarative, efficient, and flexible JavaScr...
# 4                               JavaScript Style Guide
# 5    Bring data to life with SVG, Canvas and HTML. ...
# 6     A framework for building native apps with React.
# 7      Set up a modern web app by running one command.
# 8    Node.js JavaScript runtime :sparkles::turtle::...
# 9    Promise based HTTP client for the browser and ...
# 10               The iconic SVG, font, and CSS toolkit
# 11             AngularJS - HTML enhanced for web apps!
# 12                              JavaScript 3D library.
# 13                           jQuery JavaScript Library
# 14                            Headless Chrome Node API
# 15   📝 Algorithms and data structures implemented i...
# 16   A bundler for javascript and friends. Packs ma...
# 17     Predictable state container for JavaScript apps
# 18                     :atom: The hackable text editor
# 19   React components for faster and easier web dev...
# 20                     The HTML Presentation Framework
# 21     Realtime application framework (Node.JS server)
# 22   A curated collection of useful JavaScript snip...
# 23   Semantic is a UI component framework based aro...
# 24   Fast, unopinionated, minimalist web framework ...
# 25          Simple HTML5 Charts using the <canvas> tag
# 26   A professional front-end template for building...
# 27   Parse, validate, manipulate, and display dates...
# 28                 Meteor, the JavaScript App Platform
# 29     Resumes generated using the GitHub informations
# ..                                                 ...
# 892  js2flowchart - a visualization library to conv...
# 893  Nice, downward compatible, touchable, jQuery dial
# 894                                     Swagger Editor
# 895  Serverless Examples – A collection of boilerpl...
# 896  InstantClick makes following links in your web...
# 897                           📸 Polaroid for your code
# 898  A service for server-side rendering your JavaS...
# 899  :arrow_heading_up: JavaScript Code Style check...
# 900              Node's framework for interactive CLIs
# 901  A Hassle-Free Way to Self-Host Google Fonts. G...
# 902  A Cross-end HTML5 Game development solution de...
# 903  A very intelligent browser based Webpack dashb...
# 904  Sandstorm is a self-hostable web productivity ...
# 905  Extends the default Bootstrap Modal class. Res...
# 906            Sublime-like terminal-based text editor
# 907  A delicious blend of gulp tasks combined into ...
# 908  one for all free music in china (chrome extens...
# 909  Immutable data structures for JavaScript which...
# 910   tap-producing test harness for node and browsers
# 911  Exploits locked/password protected computers o...
# 912  SyntaxHighlighter is a fully functional self-c...
# 913  Cross-platform utility that uncovers the techn...
# 914  😻 Convert any video file to an optimized anima...
# 915  Free UI Kits built on Bootstrap for any develo...
# 916                                         OpenLayers
# 917  Override create-react-app webpack configs with...
# 918     A tiny script for generating attractive colors
# 919  An adapter-based ORM for Node.js  with support...
# 920  A Vue.js plugin for lazyload your Image or Com...
# 921    A compiler for the Mustache templating language
#
#                                      full_name         id    language  \
# 0                    freeCodeCamp/freeCodeCamp   28457823  JavaScript
# 1                                    vuejs/vue   11730342  JavaScript
# 2                               twbs/bootstrap    2126244  JavaScript
# 3                               facebook/react   10270250  JavaScript
# 4                            airbnb/javascript    6498492  JavaScript
# 5                                        d3/d3     943149  JavaScript
# 6                        facebook/react-native   29028775  JavaScript
# 7                    facebook/create-react-app   63537249  JavaScript
# 8                                  nodejs/node   27193779  JavaScript
# 9                                  axios/axios   23088740  JavaScript
# 10                    FortAwesome/Font-Awesome    3470471  JavaScript
# 11                          angular/angular.js     460078  JavaScript
# 12                             mrdoob/three.js     576201  JavaScript
# 13                               jquery/jquery     167174  JavaScript
# 14                      GoogleChrome/puppeteer   90796663  JavaScript
# 15              trekhleb/javascript-algorithms  126577260  JavaScript
# 16                             webpack/webpack    3678731  JavaScript
# 17                               reduxjs/redux   36535156  JavaScript
# 18                                   atom/atom    3228505  JavaScript
# 19                         mui-org/material-ui   23083156  JavaScript
# 20                           hakimel/reveal.js    1861458  JavaScript
# 21                          socketio/socket.io     557980  JavaScript
# 22               30-seconds/30-seconds-of-code  112507086  JavaScript
# 23                    Semantic-Org/Semantic-UI    9309093  JavaScript
# 24                           expressjs/express     237159  JavaScript
# 25                            chartjs/Chart.js    8843683  JavaScript
# 26                      h5bp/html5-boilerplate     486550  JavaScript
# 27                               moment/moment    1424470  JavaScript
# 28                               meteor/meteor    3214406  JavaScript
# 29                    resume/resume.github.com    1334369  JavaScript
# ..                                         ...        ...         ...
# 892  Bogdan-Lyashenko/js-code-to-svg-flowchart   98823234  JavaScript
# 893                       aterrien/jQuery-Knob    2830198  JavaScript
# 894                 swagger-api/swagger-editor   19390712  JavaScript
# 895                        serverless/examples   73526083  JavaScript
# 896                       dieulot/instantclick   14640245  JavaScript
# 897                            octref/polacode  120965715  JavaScript
# 898                           airbnb/hypernova   60133112  JavaScript
# 899                         jscs-dev/node-jscs   10697582  JavaScript
# 900                              dthree/vorpal   41258890  JavaScript
# 901             majodev/google-webfonts-helper   28320207  JavaScript
# 902                              hiloteam/Hilo   38603315  JavaScript
# 903                              zouhir/jarvis  100657321  JavaScript
# 904                     sandstorm-io/sandstorm   15728293  JavaScript
# 905                      jschr/bootstrap-modal    5971563  JavaScript
# 906                           slap-editor/slap   18981255  JavaScript
# 907                          vigetlabs/blendid   15813955  JavaScript
# 908           listen1/listen1_chrome_extension   57430416  JavaScript
# 909               rtfeldman/seamless-immutable   25670686  JavaScript
# 910                              substack/tape    6853358  JavaScript
# 911                            samyk/poisontap   73915307  JavaScript
# 912        syntaxhighlighter/syntaxhighlighter    1173043  JavaScript
# 913                         AliasIO/Wappalyzer     514380  JavaScript
# 914                                 vvo/gifify   27015948  JavaScript
# 915        Pixelkit/PixelKit-Bootstrap-UI-Kits   13863797  JavaScript
# 916                      openlayers/openlayers    4723248  JavaScript
# 917                 timarney/react-app-rewired   65231883  JavaScript
# 918                  davidmerfield/randomColor   18573791  JavaScript
# 919                      balderdashy/waterline    9996255  JavaScript
# 920                      hilongjw/vue-lazyload   49623638  JavaScript
# 921                           twitter/hogan.js    3029324  JavaScript
#
#                            name  open_issues_count  stargazers_count  \
# 0                  freeCodeCamp               1837            303412
# 1                           vue                298            141440
# 2                     bootstrap                378            134046
# 3                         react                720            131133
# 4                    javascript                137             86208
# 5                            d3                  9             85340
# 6                  react-native                537             78150
# 7              create-react-app                385             68629
# 8                          node                964             62108
# 9                         axios                656             60784
# 10                 Font-Awesome               4804             60081
# 11                   angular.js                461             59568
# 12                     three.js                890             52397
# 13                       jquery                 82             51769
# 14                    puppeteer                400             50341
# 15        javascript-algorithms                 94             49787
# 16                      webpack                510             49407
# 17                        redux                 30             49153
# 18                         atom                665             49021
# 19                  material-ui                323             47958
# 20                    reveal.js                467             46900
# 21                    socket.io                397             46644
# 22           30-seconds-of-code                  7             45930
# 23                  Semantic-UI                904             45721
# 24                      express                164             44312
# 25                     Chart.js                449             43939
# 26            html5-boilerplate                  1             42937
# 27                       moment                335             41483
# 28                       meteor                333             41121
# 29            resume.github.com                 35             41072
# ..                          ...                ...               ...
# 892    js-code-to-svg-flowchart                 14              5154
# 893                 jQuery-Knob                222              5153
# 894              swagger-editor                 77              5151
# 895                    examples                 83              5146
# 896                instantclick                 49              5141
# 897                    polacode                 31              5138
# 898                   hypernova                 34              5128
# 899                   node-jscs                  0              5123
# 900                      vorpal                130              5118
# 901      google-webfonts-helper                 38              5104
# 902                        Hilo                  7              5103
# 903                      jarvis                 20              5100
# 904                   sandstorm                608              5093
# 905             bootstrap-modal                112              5082
# 906                        slap                114              5076
# 907                     blendid                 71              5067
# 908    listen1_chrome_extension                 81              5058
# 909          seamless-immutable                 50              5058
# 910                        tape                 91              5054
# 911                   poisontap                 90              5049
# 912           syntaxhighlighter                226              5044
# 913                  Wappalyzer                 96              5038
# 914                      gifify                 28              5038
# 915  PixelKit-Bootstrap-UI-Kits                  9              5035
# 916                  openlayers                124              5029
# 917           react-app-rewired                  2              5023
# 918                 randomColor                 11              5021
# 919                   waterline                 29              5021
# 920                vue-lazyload                121              5013
# 921                    hogan.js                 56              5004
#
#      test_coverage
# 0              NaN
# 1        94.067344
# 2        91.426432
# 3        85.097382
# 4              NaN
# 5              NaN
# 6         6.829530
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16       94.156720
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23      100.000000
# 24      100.000000
# 25       96.711834
# 26             NaN
# 27       88.352126
# 28             NaN
# 29             NaN
# ..             ...
# 892            NaN
# 893            NaN
# 894            NaN
# 895            NaN
# 896            NaN
# 897            NaN
# 898            NaN
# 899      96.666013
# 900            NaN
# 901            NaN
# 902            NaN
# 903            NaN
# 904            NaN
# 905            NaN
# 906            NaN
# 907            NaN
# 908            NaN
# 909      96.205962
# 910            NaN
# 911            NaN
# 912            NaN
# 913            NaN
# 914            NaN
# 915            NaN
# 916      85.323969
# 917            NaN
# 918            NaN
# 919     100.000000
# 920            NaN
# 921            NaN
#
# [922 rows x 8 columns]

# %% [markdown]
# Total de repositorios com mais de 5 mil estrelas

# %%
len(repos)
# Out:
# 922

# %% [markdown]
# Total de repositórios com coberturas feitas pelo Coveralls

# %%
len(df[df['test_coverage'].notnull()])
# Out:
# 168

# %% [markdown]
# Salvando em CSV

# %%
df.to_csv('repos-coveralls-{0}.csv'.format(lang))
